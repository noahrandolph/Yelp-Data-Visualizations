# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

business=pd.read_csv("yelp_business.csv")

# %matplotlib inline

# %% [markdown]
# ### yelp_business.csv

# %%
print(business.dtypes)
print(business.head())
# Out:
# business_id      object
# name             object
# neighborhood     object
# address          object
# city             object
# state            object
# postal_code      object
# latitude        float64
# longitude       float64
# stars           float64
# review_count      int64
# is_open           int64
# categories       object
# dtype: object
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# ...

# %%
print(business.tail())
# Out:
#                    business_id                           name neighborhood  \
# 174562  ALV5R8NkZ1KGOZeuZl3u0A                "Whitby Toyota"          NaN
# 174563  gRGalHVu6BcaUDIAGVW_xQ            "Village Auto Body"          NaN
# 174564  XXvZBIHoJBU5d6-a-oyMWQ                          "AAM"          NaN
# 174565  lNpPGgM96nPIYM1shxciHg  "Bronze Beauty Spray Tanning"          NaN
# 174566  viKaP26BcHU6cLx8sf4gKg             "Phoenix Pharmacy"          NaN
#
#                                address        city state postal_code  \
# 174562          "1025 Dundas Street W"      Whitby    ON     L1P 1Z1
# 174563           "3957 Brecksville Rd"   Richfield    OH       44286
# 174564   "1600 W Broadway Rd, Ste 200"       Tempe    AZ       85282
# 174565    "300 Camp Horne Rd, Ste 250"  Pittsburgh    PA       15202
# 174566  "1701 East Thomas Rd, Ste 105"     Phoenix    AZ       85016
#
#          latitude   longitude  stars  review_count  is_open  \
# ...

# %% [markdown]
# #### Which companies have the most entries in Yelp?

# %%
print(business['name'].value_counts()[:50])
# Out:
# "Starbucks"                           936
# "McDonald's"                          695
# "Subway"                              686
# "Pizza Hut"                           301
# "Taco Bell"                           293
# "Burger King"                         289
# "Walgreens"                           287
# "Wendy's"                             256
# "The UPS Store"                       242
# "Tim Hortons"                         235
# "Domino's Pizza"                      214
# "Great Clips"                         211
# "Enterprise Rent-A-Car"               200
# "Dunkin' Donuts"                      182
# "Chipotle Mexican Grill"              175
# "KFC"                                 165
# "Chase Bank"                          164
# "Wells Fargo Bank"                    160
# "Panera Bread"                        157
# "Bank of America"                     156
# "Circle K"                            147
# "Jimmy John's"                        146
# ...

# %% [markdown]
# #### What cities are represented?

# %%
print(business['city'].value_counts())
# Out:
# Las Vegas                        26775
# Phoenix                          17213
# Toronto                          17206
# Charlotte                         8553
# Scottsdale                        8228
# Pittsburgh                        6355
# Mesa                              5760
# Montréal                          5709
# Henderson                         4465
# Tempe                             4263
# Chandler                          3994
# Edinburgh                         3868
# Cleveland                         3322
# Madison                           3213
# Glendale                          3206
# Gilbert                           3128
# Mississauga                       2726
# Stuttgart                         2000
# Peoria                            1706
# Markham                           1564
# North Las Vegas                   1393
# Champaign                         1195
# Scarborough                       1095
# North York                        1092
# ...

# %% [markdown]
# #### Neighborhood a useful column or too many nulls?

# %%
pd.isnull(business.neighborhood).value_counts()
# Out:
# True     106552
# False     68015
# Name: neighborhood, dtype: int64

# %% [markdown]
# #### Which locations have the most reviews?

# %%
business.sort_values(by=['review_count'], ascending=False)
# Out:
#                    business_id  \
# 97944   4JNXUYY8wbaaDmk3BPzlWw
# 119907  RESDUcs7fIiihp38-d6_6g
# 69993   K7lWdNUhCbcnEvI0NhGewg
# 81212   cYwJA2A6I12KNkm2rtXd5g
# 139699  DkYS3arLOhA8si5uUEmHOw
# 19191   f4x1YBxkLrZg652xt2KR5g
# 80590   2weQS-RnoOBhb1KsHKyoSQ
# 124412  KskYqH1Bi7Z_61pH6Om8pg
# 21006   eoHdUeQDNgQ6WYEnP2aiRw
# 93038   ujHiaprwCQ5ewziu0Vi9rw
# 26748   SMPbvZLSMMb7KU76YNYMGg
# 80626   5LNZ67Yw9RD6nf4_UhXOjw
# 25096   iCQpiavjjPzJ5_3gPD5Ebg
# 6670    AV6weBrZFFBfRGCbcRGO4g
# 6782    rcaPajgKOJC2vo_l3xa42A
# 10567   El4FC8jcawUVgw_0EIcbaQ
# 169223  FaHADZARwnY4yvlvpnsfGA
# 170798  hihud--QRriCYZw1zZvW4g
# 112523  Wxxvi3LZbHNIDwJ-ZimtnA
# 116002  7sPNbCx7vGAaH7SbNPZ6oA
# 50087   g8OnV26ywJlZpezdBnOWUQ
# 43069   XZbuPXdyA0ZtTu3AzqtQhg
# 106267  u_vPjx925UPEG9DFOAAvFQ
# 138776  OETh78qcgDltvHULowwhJg
# 60845   MpmFFw0GE_2iRFPdsRpJbA
# 126918  na4Th5DrNauOv-c43QQFvA
# 124334  P7pxQFqr7yBKMMI2J51udw
# 24586   XXW_OFaYQkkGOGniujZFHg
# 69105   eAc9Vd6loOgRQolMXQt6FA
# ...

# %% [markdown]
# #### What about review counts of businesses *not* in Las Vegas?

# %%
business[business.city != "Las Vegas"].sort_values(by=['review_count'], ascending=False)
# Out:
#                    business_id                                         name  \
# 4137    JmI9nslLD7KZqRr__Bg6NQ   "Phoenix Sky Harbor International Airport"
# 148820  pSQFynH1VxkfSmehRXlZWw                            "Pizzeria Bianco"
# 64024   LNGBEEelQx4zbfWnlc66cw                            "Studio B Buffet"
# 152492  JzOp695tclcNCNMuBl7oxA                         "Four Peaks Brewing"
# 82317   0W4lkclzZThpx3V65bVgig                                 "Schwartz's"
# 100969  VyVIneSU7XAWgMBllI6LnQ                                    "Bobby Q"
# 115632  OgJ0KxwJcJ9R5bUK0ixCbg                                "Lux Central"
# 130242  3l54GTr8-E3XPbIxnF_sAA                       "Rehab Burger Therapy"
# 171047  9a3DrZvpYxVs3k_qwlCNSw                                       "Cibo"
# 831     frCxZS7lPhEnQRJ3UY6m7A                               "La Santisima"
# 41036   K-uQkfSUTwu5LIwPB4b_vg                       "The Mission Old Town"
# ...

# %% [markdown]
# #### What's in the column "categories?"

# %%
print(business['categories'].value_counts()[:50])
# Out:
# Restaurants;Pizza                                   990
# Pizza;Restaurants                                   987
# Food;Coffee & Tea                                   978
# Nail Salons;Beauty & Spas                           936
# Coffee & Tea;Food                                   929
# Beauty & Spas;Nail Salons                           909
# Mexican;Restaurants                                 906
# Restaurants;Mexican                                 864
# Restaurants;Chinese                                 857
# Beauty & Spas;Hair Salons                           839
# Chinese;Restaurants                                 839
# Hair Salons;Beauty & Spas                           781
# Restaurants;Italian                                 615
# Italian;Restaurants                                 554
# Auto Repair;Automotive                              551
# Grocery;Food                                        538
# Food;Grocery                                        522
# ...

# %%
print(business['categories'].value_counts()[-50:])
# Out:
# Event Planning & Services;Japanese;Sushi Bars;Restaurants;Venues & Event Spaces                                                                               1
# Bakeries;Pet Groomers;Pets;Pet Stores;Pet Services;Food                                                                                                       1
# Health & Medical;Cosmetic Dentists;Endodontists;Dentists;General Dentistry                                                                                    1
# Cocktail Bars;Nightlife;Bars;Distilleries;Food                                                                                                                1
# Nightlife;Restaurants;Bars;American (New);Soup;Italian                                                                                                        1
# Italian;Bars;Restaurants;Wine Bars;Lounges;Nightlife;Food;Pizza;Coffee & Tea;Sports Bars                                                                      1
# ...

# %% [markdown]
# #### What's in the is_open column?

# %%
print(business['is_open'].value_counts()[:50])
# Out:
# 1    146702
# 0     27865
# Name: is_open, dtype: int64

# %% [markdown]
# #### Just breweries

# %%
breweries = business['categories'].str.extract('(?P<brew>(Brew))', expand=True)
brew_biz = business[breweries.notnull()['brew']]

brew_biz.sort_values(by=['review_count'], ascending=False)
# Out:
#                    business_id                                     name  \
# 152492  JzOp695tclcNCNMuBl7oxA                     "Four Peaks Brewing"
# 78766   EAwh1OmG6t6p3nRaZOW_AA   "Ellis Island Hotel, Casino & Brewery"
# 116943  mD7zqv7Y3kvsa_p_MtTayg                 "SanTan Brewing Company"
# 108743  mnwRtuVQEsIUomBchu0gwg                  "OHSO Brewery- Arcadia"
# 170252  sJNcipFYElitBrtiJx0ezQ             "Arizona Wilderness Brewing"
# 81979   ejaUQ1hYo7Q7xCL1HdPINw                      "Church Brew Works"
# 159660  dNr7VKRti8dXWE-jzfVBtQ                "The Perch Pub & Brewery"
# 72740   meXjqyhTNLFmknY39y2sMg            "Great Lakes Brewing Company"
# 78478   EgtyW19V-64c6PmRuvzSEA                         "The Great Dane"
# 45524   wmCBxE0PfLZD8sxIwAY59Q                 "Hofbrauhaus Pittsburgh"
# 165859  uI-dbKk_9cUen7pi3-16Sg            "BJ's Restaurant & Brewhouse"
# 170606  lpYFsXFrojiBZ1kbWR2lZw                 "Four Peaks Grill & Tap"
# ...

# %% [markdown]
# #### Just Vegas Starbucks

# %%
x = business[business.city == "Las Vegas"]['stars'].value_counts()
x = x.sort_index()
x.plot(kind='bar')
#plot
plt.title("Las Vegas Star Rating Distribution")
plt.ylabel('# of businesses', fontsize=12)
plt.xlabel('Star Ratings ', fontsize=12)
# Out:
# Text(0.5,0,'Star Ratings ')
